# %%
# !python run.py -y /nobackup/jakravit/git/DE-WQ/conf/cyanosat_conf_rrs_admix_3nm.yaml
# Out:
# DONE
# Cuda available: False
#
# Sensors: dict_keys(['hico'])
#
#
# admix min: 0.0
# admix max: 1.0
# admix mean: 0.3288238675905474
# admix stdDev: 0.36314062035010813
# admix 50th percentile: 0.2
# admix 75th percentile: 0.6
#
# Train/test/val split: stratified
#
# preprocessed train: (52880, 100)
# train input: (52880, 100)
# preprocessed test: (6609, 100)
# test input: (6609, 100)
# preprocessed val: (6609, 100)
# val input: (6609, 100)
#
#  DE(
#   (model_0): GaussianMLP(
#     (seq): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=100, out_features=100, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=100, out_features=100, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=100, out_features=100, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=100, out_features=2, bias=True)
#     )
#   )
#   (model_1): GaussianMLP(
#     (seq): Sequential(
# ...
