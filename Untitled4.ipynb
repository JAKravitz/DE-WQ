# %%
# !python run.py -y /nobackup/jakravit/git/DE-WQ/conf/cyanosat_conf_rrs_pc_5nm.yaml
# Out:
# DONE
# Cuda available: False
#
# Sensors: dict_keys(['hico'])
#
#
# PC min: 0.0
# PC max: 58661.02349422567
# PC mean: 253.15098720015
# PC stdDev: 1406.5294299598288
# PC 50th percentile: 0.6560412743540782
# PC 75th percentile: 12.756202019813538
#
# Train/test/val split: stratified
#
# preprocessed train: (52880, 60)
# train input: (52880, 60)
# preprocessed test: (6609, 60)
# test input: (6609, 60)
# preprocessed val: (6609, 60)
# val input: (6609, 60)
#
#  DE(
#   (model_0): GaussianMLP(
#     (seq): Sequential(
#       (0): Linear(in_features=60, out_features=100, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=100, out_features=100, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=100, out_features=100, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=100, out_features=100, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=100, out_features=2, bias=True)
#     )
#   )
#   (model_1): GaussianMLP(
#     (seq): Sequential(
# ...
